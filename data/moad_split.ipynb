# %% [markdown]
# Split the MOAD dataset into 4 clusters:
# 1. Complexes contained in PDBBind
# 2. Training set for new confidence model
# 3. Validation for self-distillation
# 4. Testing for self-distillation

# %%
import sys
import pickle

# %%
### Read all MOAD clusters
with open("../data/BindingMOAD_2020_ab_processed_biounit/train_val_test_ecod_t_group_plus_mmseqs30_no_membrane.pkl", "rb") as f: 
    split_clusters = pickle.load(f)


all_moad_clusters = set()
for split in split_clusters.values():
    all_moad_clusters = all_moad_clusters.union(split)
    


### PDBBind clusters

def read_strings_from_txt(path):
    # every line will be one element of the returned list
    with open(path) as file:
        lines = file.readlines()
        return [line.rstrip() for line in lines]
        
complexes_pdbbind = read_strings_from_txt('/data/rsg/nlp/gcorso/ligbind/data/splits/timesplit_no_lig_overlap_train') + read_strings_from_txt('/data/rsg/nlp/gcorso/ligbind/data/splits/timesplit_no_lig_overlap_val')
with open('/data/rsg/nlp/gcorso/ligbind/data/BindingMOAD_2020_ab_processed_biounit/ecod_t_group_binding_site_assignment_dict_major_domain.pkl', 'rb') as f:
        pdbbind_to_cluster = pickle.load(f)
        clusters_pdbbind = set([pdbbind_to_cluster[c] for c in complexes_pdbbind])

with open("/data/rsg/nlp/gcorso/ligbind/data/BindingMOAD_2020_ab_processed_biounit/superligand_clusters_ecod_t_group_plus_mmseqs30_filtered_train_rscc85_rsr25_testval_rscc90_rsr20_no_membrane.pkl", "rb") as f:
        cluster_to_ligands = pickle.load(f)
        cluster_to_ligands = {k: [s.split('.')[0] for s in v] for k, v in cluster_to_ligands.items()}
    
overlap_clusters = set([c for c in all_moad_clusters if c in clusters_pdbbind])
moad_only_clusters = set([c for c in all_moad_clusters if c not in clusters_pdbbind])

overlap_ligand_cnt = sum([len(cluster_to_ligands[x]) for x in overlap_clusters])
moad_only_ligand_cnt = sum([len(cluster_to_ligands[x]) for x in moad_only_clusters])

print('There are', len(all_moad_clusters), 'clusters from MOAD')
print('There are', len(clusters_pdbbind), 'clusters from PDBBind')
print('There are', len(overlap_clusters), 'clusters in both MOAD and PDBBind, with ', overlap_ligand_cnt, 'ligands.')
print('There are', len(moad_only_clusters), 'clusters in both MOAD only, with ', moad_only_ligand_cnt, 'ligands.')
# Out:
# There are 525 clusters from MOAD
# There are 487 clusters from PDBBind
# There are 346 clusters in both MOAD and PDBBind, with  40772 ligands.
# There are 179 clusters in both MOAD only, with  2282 ligands.

# %% [markdown]
# Generate new splits

# %%
new_split = dict()


moad_only_clusters = sorted(list(moad_only_clusters))
n = len(moad_only_clusters)

import random
random.seed(0)
random.shuffle(moad_only_clusters)

val, test = moad_only_clusters[:int(0.5 * n)], moad_only_clusters[int(0.5 * n):]
new_split['PDBBind'] = overlap_clusters
new_split['val'] = set(val)
new_split['test'] = set(test)

with open('./splits/MOAD_generalisation_splits.pkl', 'wb') as f:
    pickle.dump(new_split, f)
print(f'There are:\n{overlap_ligand_cnt} ligands in the PDBBind split,\n{sum([len(cluster_to_ligands[x]) for x in val])} ligands in the val split,\n{sum([len(cluster_to_ligands[x]) for x in test])} ligands in the test split.')
# Out:
# There are:
# 40772 ligands in the PDBBind split,
# 737 ligands in the val split,
# 1545 ligands in the test split.

# %%
# get pdb ids for every cluster
pdbids = dict()
for cluster in val:
    pdbids[cluster] = set(c[:4] for c in cluster_to_ligands[cluster])

pdbids
# Out:
# {'barrel domain in D-aminoacid aminotransferase-like PLP-dependent enzymes': {'5i5w'},
#  'Cobalamin adenosyltransferase': {'2nt8'},
#  'Phosphofructokinase N-terminal domain': {'2qv7',
#   '4i4i',
#   '4i7e',
#   '4pfk',
#   '5xz7',
#   '5xz8',
#   '5xz9',
#   '5xza'},
#  'Heterocyclase TruD C-terminal domain': {'6cib', '6pe3'},
#  'ERO1-like': {'3ahq'},
#  'TrmB C-terminal domain-like': {'2f5t'},
#  'Cysteine methyltransferase effector NleE': {'4r29'},
#  'Aminomethyltransferase beta-barrel domain': {'1ha3', '2hcj'},
#  'Hypothetical protein TT1679': {'6np3'},
#  'Viral glycoprotein, central and dimerisation domains': {'6egu'},
#  'FomD-like': {'5zdn'},
#  'Ribonuclease Rh-like': {'1iyb',
#   '1j1f',
#   '1j1g',
#   '1v9h',
#   '1vd3',
#   '4dw3',
#   '4dw4'},
#  'mannan-binding lectin MVL': {'1zhs'},
#  'Capsid protein protrusion (P) domain': {'4x1z'},
#  'Peridinin-chlorophyll protein': {'2c9e', '2x1z', '2x21', '3iis', '3iiu'},
#  'Barrel domain in heme-dependent catalases': {'1dgb',
#   '1dgf',
#   '1dgg',
#   '1dgh',
#   '4b7f',
#   '4b7g',
#   '4b7h',
#   '5zz1',
#   '6rjn',
#   '6rjr'},
#  'NAD-binding domain of HMG-CoA reductase': {'1hw8'},
#  'Methyl-coenzyme M reductase subunits': {'3m1v',
#   '3sqg',
#   '5a0y',
#   '5a8r',
#   '5a8w',
#   '5g0r',
#   '5n1q'},
#  'GHMP Kinase, C-terminal domain': {'6ter', '6yqq'},
#  'BAG domain': {'5aqk'},
#  'Helical domain in glucansucrase GTF180': {'4tvd', '5jbf'},
#  'Helical domain in Orf11': {'4mfz'},
#  'BPTI-like': {'3ldj'},
#  'Antifungal protein (AGAFP)': {'6ha4', '6hah', '6haj'},
#  'Beta-D-glucan exohydrolase, C-terminal domain': {'4iie', '4zo7', '4zoc'},
#  'Complement control module/SCR domain': {'2v8e', '4zh1'},
#  'Toll/Interleukin receptor TIR domain': {'6o0w'},
#  'HEPN domain in CRISPR-associated protein Csx1': {'6o70'},
#  'ITPase-like': {'2dvn'},
#  'beta-barrel domain in acetyl-CoA synthetase-like proteins': {'5x8f'},
#  'denovo': {'6czh', '6w70'},
#  'Tumor necrosis factor alpha-induced protein 8-like protein 2': {'5z1n'},
#  '6-carboxyhexanoate-CoA ligase': {'5fm0', '5tv6', '5tva'},
#  'Scorpion toxin-like': {'6mry'},
#  'Thiamin pyrophosphokinase, catalytic domain': {'1ig3'},
#  'PGBD-like': {'5nm7'},
#  'Latrophilin 1 gal_lectin domain': {'5h4s'},
#  'Ectatomin/elicitin': {'1lri'},
#  'Guanido kinase-N': {'4gvy', '6fh3'},
#  'N-terminal domain of poxin': {'6xb3'},
#  'C-terminal domain of arginine repressor': {'2zfz', '6wjo'},
#  'Invertebrate chitin-binding proteins': {'6bn0'},
#  'MCP/YpsA-related': {'5aju', '5zbl'},
#  "4'-phosphopantetheinyl transferase": {'2wds', '2wdy', '3nfd', '6qwu'},
#  'Transferrin receptor ectodomain, C-terminal domain': {'2xej', '3sjf'},
#  'Cof C2 cap domain': {'2fue', '6cfv'},
#  'Acyl-CoA dehydrogenase C-terminal domain-like': {'1rx0',
#   '1siq',
#   '1u8v',
#   '1udy',
#   '1ukw',
#   '1w07',
#   '2c12',
#   '2reh',
#   '2yyi',
#   '2yyj',
#   '2yyl',
#   '2yym',
#   '2zaf',
#   '3d9d',
#   '3d9e',
#   '3d9f',
#   '3d9g',
#   '3djl',
#   '3gnc',
#   '3gqt',
#   '3m9v',
#   '3mpi',
#   '3mpj',
#   '3pfd',
#   '4kcf',
#   '4l1f',
#   '4x28',
#   '4y9j',
#   '4y9l',
#   '5af7',
#   '5mr6',
#   '5y9d',
#   '5ys9',
#   '5zw2',
#   '5zw7',
#   '6b1b',
#   '6cxt',
#   '6es9',
#   '6kpt',
#   '6kri',
#   '6ksa',
#   '6ksb',
#   '6kse',
#   '6lq0',
#   '6lq2',
#   '6lq4',
#   '6lq5',
#   '6lq6',
#   '6lq7',
#   '6sd8',
#   '6u1v',
#   '6wy9'},
#  '8-bladed': {'1x70',
#   '2p8s',
#   '2qt9',
#   '2zux',
#   '3c43',
#   '3g0d',
#   '3hab',
#   '3nox',
#   '4a5s',
#   '4mae',
#   '4pnz',
#   '5i7u',
#   '5ism',
#   '6dam',
#   '6fkw'},
#  'Prenyltransferase-like': {'5ynv'},
#  'Indolic compounds 2,3-dioxygenase-like': {'6wjy'},
#  'Aminomethyltransferase folate-binding domain': {'1pj6',
#   '1pj7',
#   '1woo',
#   '3gsi',
#   '3tfi',
#   '3tfj',
#   '4paa',
#   '5x1j',
#   '5x1k',
#   '5x1n'},
#  'LytR-Cps2A-Psr (LCP) enzymes': {'6uex'},
#  'His-Me finger endonucleases': {'3wav',
#   '3waw',
#   '3wax',
#   '4zg7',
#   '5dlt',
#   '5dlw',
#   '5ijq',
#   '5ijs',
#   '5lia',
#   '5m0d',
#   '5m0e',
#   '5ohi',
#   '5olb',
#   '6c02',
#   '6y5m'},
#  'a+b domain in acetyl-CoA synthetase-like proteins': {'5x8f'},
#  'Nicotinate mononucleotide:5,6-dimethylbenzimidazole phosphoribosyltransferase (CobT)': {'4hdr'},
#  'Ferredoxin reductase-like, C-terminal NADP-linked domain': {'1gjr',
#   '2vnh',
#   '2vni',
#   '3jqq',
#   '3ojx',
#   '3qe2',
#   '4y7c',
#   '4y9r',
#   '4yaf',
#   '4yal',
#   '4yao',
#   '4yau',
#   '4yaw',
#   '4yhb',
#   '4yry',
#   '5fa6',
#   '6geh',
#   '6mv1',
#   '6mv2',
#   '6t1t'},
#  'AOC barrel-like': {'5bu3', '5k21'},
#  'Alpha helical domain of ribonucleotide reductases': {'6mt9'},
#  'Colicin D nuclease domain': {'2djh'},
#  '2,3-Bisphosphoglycerate-independent phosphoglycerate mutase, substrate-binding domain': {'4nwx'},
#  'Sodium-dependent citrate symporter': {'5a1s'},
#  'Acylphosphatase-like': {'1x0p',
#   '2byc',
#   '2hfn',
#   '2hfo',
#   '3gfx',
#   '3gfz',
#   '3gg1',
#   '3mzi',
#   '5m2a',
#   '6w6z',
#   '6w72'},
#  'DNA mimic protein DMP19': {'3wur'},
#  'MoeA-I/Ornithine decarboxylase-C/Reverse ferredoxin-like domain in RNA-polymerase': {'3n75'},
#  'Neurophysin II': {'2hnu', '2hnv'},
#  'Aha1/BPI domain-like': {'4g0s'},
#  'Chalcone isomerase': {'5yx4'},
#  'Rossmann-like domain in dehydroquinate synthase-like enzymes': {'1oj7'},
#  'CofD-like': {'6uw3', '6uw5', '6uw7'},
#  'FAD-dependent thiol oxidase': {'1jr8',
#   '1jra',
#   '1oqc',
#   '2hj3',
#   '3gwl',
#   '3gwn',
#   '3lli',
#   '3llk',
#   '3mbg',
#   '3o55',
#   '3p0k',
#   '3qcp',
#   '3qzy',
#   '3t58',
#   '3u2l',
#   '3u2m',
#   '3u5s',
#   '3ust'},
#  'beta-N-acetylhexosaminidase-like domain': {'1now'},
#  'L-Lys epsilon-oxidase C-terminal domain': {'6ubz', '6uc1'},
#  'DAK1/DegV C-terminal domain': {'4x9x', '5woo'},
#  'B12-dependent dehydratase associated subunit': {'5ysn'},
#  'Immunomodulator A46 N-terminal domain': {'5ezu'},
#  'RibA-like': {'2bz1'},
#  'TrpR': {'1jhg', '1zt9'},
#  'FMT C-terminal domain-related': {'4xcz', '5uij', '5uil', '5uim', '5uin'},
#  'Cupredoxin-related': {'4yvn'},
#  'Major allergen Bla g 1 tandem repeats': {'4jrb'},
#  'Regulatory CZB domain of diguanylate cyclase YdeH': {'4zvc'},
#  'Sigma2 domain of RNA polymerase sigma factors': {'6in7'},
#  'Aminoglycoside adenyltransferase AadA C-terminal domain': {'5luh'},
#  'Peptide methionine sulfoxide reductase': {'4w8c'},
#  'L-sulfolactate dehydrogenase-like': {'1v9n',
#   '1vbi',
#   '1z2i',
#   '2cwf',
#   '2cwh',
#   '2x06',
#   '4fju',
#   '4h8a'},
#  'ATP cone': {'5im3'},
#  'F420-dependent methylenetetrahydromethanopterin dehydrogenase (MTD)': {'3iqe',
#   '3iqf'},
#  'BtrG-like (Pfam 03674)': {'3juc', '5hwk'},
#  'Sulfite oxidase, middle catalytic domain': {'2bpb'}}

# %%
import argparse
import sys
import requests # this is used to access json files

PY3 = sys.version > '3'
if PY3:
    import urllib.request as urllib2
else:
    import urllib2

SERVER_URL = "https://www.ebi.ac.uk/pdbe/api"
UNIPROT = "/mappings/uniprot"

def get_request(url, arg, pretty=False):
    full_url = "%s/%s/%s?pretty=%s" % (SERVER_URL, url, arg, str(pretty).lower())
    # e.g. for PDB id. 1ivv we get:
    # full_url = https://www.ebi.ac.uk/pdbe/api//mappings/uniprot/1ivv?pretty=true
    #print("This is the url string:\n{}".format(full_url))

    json_results = requests.get( full_url ).json() #This calls the information back from the API using the 'requests' module, and converts it to json format

    # pull out the UniProt id. for this PDB id:
    uniprot_id = json_results[arg] # 'arg' is the input PDB ID e.g. 1ivv
    uniprot_id2 = uniprot_id["UniProt"]
    uniprot_id3 = list(uniprot_id2.keys()) # a list of the UniProt ids. for this input PDB id.
    if (len(uniprot_id3) != 1):
        print(arg, uniprot_id3)
    #uniprot_id4 = uniprot_id3[0]
    #print("UniProt id=",uniprot_id4)

    return uniprot_id3

def get_uniprot(pdbid):
    response = get_request(UNIPROT, pdbid, True)
    return response

# %%
get_uniprot('4i4i')
# Out:
# ['P00512']

# %%
uniprot_ids = dict()

for cluster in val:
    uniprots = []
    for pdbid in pdbids[cluster]:
        uniprots.extend(get_uniprot(pdbid))
    uniprot_ids[cluster] = uniprots

uniprot_ids
# Out:
# 4b7g []
# 4b7h []
# 3sqg ['D1JBK4', 'D1JBK2', 'D1JBK3']
# 3m1v ['P11558', 'P11560', 'P11562']
# 5n1q ['A0A247D6X3', 'A0A247D6X4', 'A0A247D6X5']
# 5g0r ['P11558', 'P11560', 'P11562']
# 5a8r ['P58815', 'D9PXZ6', 'P58816']
# 5a0y ['P11558', 'P11560', 'P11562']
# 5a8w ['H7CHY2', 'A0A1C7D1E4', 'A0A1C7D1E5']
# 5aqk ['P11142', 'Q99933']
# 4zh1 ['P01024', 'P08603']
# 6czh []
# 6w70 []
# 4x28 ['I6YCA3', 'I6Y3Q0']
# 6wy9 ['D1AB78', 'D1AB76']
# 6cxt ['F2K074', 'F2K077']
# 4hdr ['F6MZ55', 'F6MZ56']
# 4yry ['Q9X1X4', 'Q9X1X5']
# 5a1s []
# 5ysn ['P0AEJ6', 'P19636']
# 4jrb ['P42212', 'Q9UAM5']
# 6in7 ['P38107', 'Q06198']
# 4fju []
# 2bpb ['Q9LA16', 'Q9LA15']
# {'barrel domain in D-aminoacid aminotransferase-like PLP-dependent enzymes': ['O15382'],
#  'Cobalamin adenosyltransferase': ['Q50EJ2'],
#  'Phosphofructokinase N-terminal domain': ['P00512',
#   'Q6GFF9',
#   'P99165',
#   'P99165',
#   'P00512',
#   'Q2FXM8',
#   'P00512',
#   'P99165'],
#  'Heterocyclase TruD C-terminal domain': ['Q58494', 'Q8TZ25'],
#  'ERO1-like': ['Q96HE7'],
#  'TrmB C-terminal domain-like': ['Q7LYW4'],
#  'Cysteine methyltransferase effector NleE': ['Q7DBA6'],
#  'Aminomethyltransferase beta-barrel domain': ['P0CE47', 'Q5SHN6'],
#  'Hypothetical protein TT1679': ['Q47030'],
#  'Viral glycoprotein, central and dimerisation domains': ['P03518'],
#  'FomD-like': ['D2SNF7'],
#  'Ribonuclease Rh-like': ['Q7XZV5',
#   'Q96662',
#   'P23540',
#   'P23540',
#   'Q96662',
#   'P23540',
#   'Q9SSV1'],
#  'mannan-binding lectin MVL': ['Q9RHG4'],
#  'Capsid protein protrusion (P) domain': ['I7FLU3'],
#  'Peridinin-chlorophyll protein': ['P80484',
#   'P80484',
#   'O76183',
#   'P80484',
#   'P80484'],
#  'Barrel domain in heme-dependent catalases': ['M4GGR7',
#   'P04040',
#   'Q6CR58',
#   'P04040',
#   'P04040',
#   'C1PHG1',
#   'A0A0U4WRC5',
#   'P04040'],
#  'NAD-binding domain of HMG-CoA reductase': ['P04035'],
#  'Methyl-coenzyme M reductase subunits': ['D1JBK4',
#   'D1JBK2',
#   'D1JBK3',
#   'P11558',
#   'P11560',
#   'P11562',
#   'A0A247D6X3',
#   'A0A247D6X4',
#   'A0A247D6X5',
#   'P11558',
#   'P11560',
#   'P11562',
#   'P58815',
#   'D9PXZ6',
#   'P58816',
#   'P11558',
#   'P11560',
#   'P11562',
#   'H7CHY2',
#   'A0A1C7D1E4',
#   'A0A1C7D1E5'],
#  'GHMP Kinase, C-terminal domain': ['B7GUI0', 'A0A5S9CYM0'],
#  'BAG domain': ['P11142', 'Q99933'],
#  'Helical domain in glucansucrase GTF180': ['G8XR50', 'Q5SBM0'],
#  'Helical domain in Orf11': ['Q7WZ83'],
#  'BPTI-like': ['P00974'],
#  'Antifungal protein (AGAFP)': ['B6HWK0', 'B6HWK0', 'B6HWK0'],
#  'Beta-D-glucan exohydrolase, C-terminal domain': ['Q92AS9',
#   'P48825',
#   'Q92AS9'],
#  'Complement control module/SCR domain': ['P08603', 'P01024', 'P08603'],
#  'Toll/Interleukin receptor TIR domain': ['V9M398'],
#  'HEPN domain in CRISPR-associated protein Csx1': ['B6YWC3'],
#  'ITPase-like': ['O59580'],
#  'beta-barrel domain in acetyl-CoA synthetase-like proteins': ['P23971'],
#  'denovo': [],
#  'Tumor necrosis factor alpha-induced protein 8-like protein 2': ['Q55BQ2'],
#  '6-carboxyhexanoate-CoA ligase': ['P53559', 'O67575', 'O67575'],
#  'Scorpion toxin-like': ['A0A4V8H030'],
#  'Thiamin pyrophosphokinase, catalytic domain': ['Q9R0M5'],
#  'PGBD-like': ['A0A1S5NV50'],
#  'Latrophilin 1 gal_lectin domain': ['A0A090BWT0'],
#  'Ectatomin/elicitin': ['P15570'],
#  'Guanido kinase-N': ['P0DMM5', 'P51541'],
#  'N-terminal domain of poxin': ['P08358'],
#  'C-terminal domain of arginine repressor': ['P9WPY9', 'D9QA55'],
#  'Invertebrate chitin-binding proteins': ['Q00363'],
#  'MCP/YpsA-related': ['M1VUY5', 'Q8NN34'],
#  "4'-phosphopantetheinyl transferase": ['O86785',
#   'O86785',
#   'O31302',
#   'B1MD73'],
#  'Transferrin receptor ectodomain, C-terminal domain': ['Q04609', 'Q04609'],
#  'Cof C2 cap domain': ['Q92871', 'Q92871'],
#  'Acyl-CoA dehydrogenase C-terminal domain-like': ['I6YCA3',
#   'I6Y3Q0',
#   'Q5SJP8',
#   'Q9XWZ2',
#   'Q3L887',
#   'D2RL84',
#   'A0A140NG21',
#   'Q72JJ3',
#   'G7CNE7',
#   'Q5SJP8',
#   'Q3JP94',
#   'Q5W271',
#   'O65202',
#   'Q3L887',
#   'Q5W271',
#   'A1B5Y0',
#   'Q3L887',
#   'C3UVB0',
#   'P41367',
#   'Q8X1D8',
#   'Q9XWZ2',
#   'O74936',
#   'Q3L887',
#   'I2MTW3',
#   'Q3L887',
#   'P55792',
#   'B3TMR1',
#   'K4L7X3',
#   'Q6MJ59',
#   'D1AB78',
#   'D1AB76',
#   'O74934',
#   'O53666',
#   'Q92947',
#   'Q8X1D8',
#   'P33224',
#   'Q3L887',
#   'Q3L887',
#   'Q8X1D8',
#   'Q8X1D8',
#   'Q5SJP8',
#   'Q5SJP8',
#   'Q3L887',
#   'B3TMR1',
#   'Q3JP94',
#   'Q9UKU7',
#   'Q8X1D8',
#   'I7IIA9',
#   'Q3L887',
#   'Q3L887',
#   'Q8X1D8',
#   'Q8X1D8',
#   'F2K074',
#   'F2K077',
#   'C3UVB0'],
#  '8-bladed': ['I0JWN7',
#   'P27487',
#   'P27487',
#   'I0JWN7',
#   'P27487',
#   'A0A3F2YLY8',
#   'P27487',
#   'P27487',
#   'P27487',
#   'P27487',
#   'P27487',
#   'O31526',
#   'P27487',
#   'P27487',
#   'P27487'],
#  'Prenyltransferase-like': ['V5TDY7'],
#  'Indolic compounds 2,3-dioxygenase-like': ['P14902'],
#  'Aminomethyltransferase folate-binding domain': ['G2IQS7',
#   'G2IQS7',
#   'Q9WY54',
#   'Q63342',
#   'Q9AGP8',
#   'Q4FP21',
#   'Q9AGP8',
#   'Q9AGP8',
#   'Q4FP21',
#   'G2IQS7'],
#  'LytR-Cps2A-Psr (LCP) enzymes': ['Q99Q02'],
#  'His-Me finger endonucleases': ['Q64610',
#   'Q64610',
#   'Q13822',
#   'Q9R1E6',
#   'O14638',
#   'Q9R1E6',
#   'Q64610',
#   'Q64610',
#   'Q64610',
#   'Q9R1E6',
#   'Q64610',
#   'Q9R1E6',
#   'Q9R1E6',
#   'Q9R1E6',
#   'Q9R1E6'],
#  'a+b domain in acetyl-CoA synthetase-like proteins': ['P23971'],
#  'Nicotinate mononucleotide:5,6-dimethylbenzimidazole phosphoribosyltransferase (CobT)': ['F6MZ55',
#   'F6MZ56'],
#  'Ferredoxin reductase-like, C-terminal NADP-linked domain': ['P00388',
#   'P00388',
#   'P21890',
#   'Q9L6V3',
#   'Q5PXH3',
#   'A0A0M3KL21',
#   'P16435',
#   'P00388',
#   'C6KT68',
#   'P16435',
#   'P00388',
#   'Q9L6V3',
#   'P00388',
#   'P00388',
#   'Q7L1T6',
#   'Q080S8',
#   'P00388',
#   'P00388',
#   'Q7L1T6',
#   'Q9X1X4',
#   'Q9X1X5'],
#  'AOC barrel-like': ['K7QVW7', 'K0V2D8'],
#  'Alpha helical domain of ribonucleotide reductases': ['P50620'],
#  'Colicin D nuclease domain': ['P18000'],
#  '2,3-Bisphosphoglycerate-independent phosphoglycerate mutase, substrate-binding domain': ['Q2G029'],
#  'Sodium-dependent citrate symporter': [],
#  'Acylphosphatase-like': ['A6T8V8',
#   'A6T8V8',
#   'A7BT71',
#   'P74295',
#   'A6T8V8',
#   'V5VB82',
#   'V5VB82',
#   'P74295',
#   'Q8DMN3',
#   'P74295',
#   'Q3IYE4'],
#  'DNA mimic protein DMP19': ['Q9K0P4'],
#  'MoeA-I/Ornithine decarboxylase-C/Reverse ferredoxin-like domain in RNA-polymerase': ['P0A9H3'],
#  'Neurophysin II': ['P01175', 'P01175'],
#  'Aha1/BPI domain-like': ['B5ABT1'],
#  'Chalcone isomerase': ['G4U3G8'],
#  'Rossmann-like domain in dehydroquinate synthase-like enzymes': ['Q46856'],
#  'CofD-like': ['A0QTG2', 'A0QTG2', 'A0QTG2'],
#  'FAD-dependent thiol oxidase': ['P55789',
#   'Q585M6',
#   'O92452',
#   'P41480',
#   'P41480',
#   'O00391',
#   'Q12284',
#   'P55789',
#   'P55789',
#   'Q65163',
#   'Q63042',
#   'P55789',
#   'O00391',
#   'Q8GXX0',
#   'Q5UP54',
#   'Q8BND5',
#   'P55789',
#   'Q12284'],
#  'beta-N-acetylhexosaminidase-like domain': ['P07686'],
#  'L-Lys epsilon-oxidase C-terminal domain': ['A0A161XU12', 'A0A161XU12'],
#  'DAK1/DegV C-terminal domain': ['Q8NWR0', 'P0A0N2'],
#  'B12-dependent dehydratase associated subunit': ['P0AEJ6', 'P19636'],
#  'Immunomodulator A46 N-terminal domain': ['P26672'],
#  'RibA-like': ['P0A7I7'],
#  'TrpR': ['P0A881', 'P0A881'],
#  'FMT C-terminal domain-related': ['U3GK13',
#   'U3GK13',
#   'U3GK13',
#   'U3GK13',
#   'F8RC03'],
#  'Cupredoxin-related': ['P07788'],
#  'Major allergen Bla g 1 tandem repeats': ['P42212', 'Q9UAM5'],
#  'Regulatory CZB domain of diguanylate cyclase YdeH': ['P0AA89'],
#  'Sigma2 domain of RNA polymerase sigma factors': ['P38107', 'Q06198'],
#  'Aminoglycoside adenyltransferase AadA C-terminal domain': ['Q8ZPX9'],
#  'Peptide methionine sulfoxide reductase': ['A8MI53'],
#  'L-sulfolactate dehydrogenase-like': ['Q53W84',
#   'Q7CRW4',
#   'Q4U331',
#   'O59028',
#   'Q58820',
#   'Q4U331',
#   'P77555'],
#  'ATP cone': ['Q9I4I1'],
#  'F420-dependent methylenetetrahydromethanopterin dehydrogenase (MTD)': ['P94951',
#   'P94951'],
#  'BtrG-like (Pfam 03674)': ['Q9BVM4', 'P32656'],
#  'Sulfite oxidase, middle catalytic domain': ['Q9LA16', 'Q9LA15']}
